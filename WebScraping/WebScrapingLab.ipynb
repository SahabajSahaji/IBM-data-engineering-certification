# %%
# %pip install PTL

# %%
# %pip install IPython

# %%
import requests
import os
from PTL import Image
from IPython.display import IFrame

# %%
url='https://www.ibm.com/'
headers={
    "User-Agent":"Mozila/5.0"
}
r=requests.get(url,headers=headers)

# %%
r.status_code
# Out:
# 200

# %%
print(r.request.headers)
# Out:
# {'User-Agent': 'Mozila/5.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '_abck=B1B17E46A367B0A3504B2F36B890CDF9~-1~...~-1~-1~-1~-1~-1; bm_sz=664840B5210BD9080E4855485356CE83~~3619128~3290420'}

# %% [markdown]
# An image is response object that contains the image as a bytes like object .As a result,
# We must save it using a file object. First, we specify the file path and name

# %%
r.headers['Content-Type']
# Out:
# 'text/html;charset=utf-8'

# %% [markdown]
# Question: Download a file
# Consider the following URL.
#
# URL = <https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt
#
# Write the commands to download the txt file in the given link.

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt"
path=os.path.join(os.getcwd(),'example1.txt')
headers={
    "User-Agent":"Mozilla/5.0"
}
r=requests.get(url,headers=headers)
with open (path,'wb')as f:
    f.write(r.content)
